# %%
## Date injestion

# %%
### documents data strcture 
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content i am using th create RAG",
    metaData={
        "source": "sample.txt",
        "author": "Abi",
        "page": 1,
        "date_created": "2024-01-01"
    }
)
doc
# Out:
# Document(metadata={}, page_content='this is the main text content i am using th create RAG')

# %%
## creating a simpe txt fi e
import os 
os.makedirs("data/text_files", exist_ok=True)

# %%
## Text load 

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/sample.txt",encoding="utf-8")
docuements=loader.load()
print(docuements)
# Out:
# [Document(metadata={'source': '../data/text_files/sample.txt'}, page_content='Chapter 7\nRetrieval-Augmented Generation\nFilippo Bianchini\nAbstract Retrieval-augmented generation (RAG) has emerged as a transformative\napproach to enhancing the capabilities of large language models (LLMs) by\nintegrating real-time information retrieval with generative text synthesis. Traditional\nLLMs rely on pre-trained data, limiting their effectiveness when handling tasks\nrequiring up-to-date or domain-specific information. RAG addresses this constraint\nby embedding a retrieval mechanism within the LLM framework, allowing the\nmodel to access external knowledge sources dynamically. This integration enables\nLLMs to generate contextually relevant and factually accurate responses, extending\ntheir utility within the realm of information systems (IS), where timely and\nprecise information is critical. Starting from the history and evolution of retrievalaugmented generation, passing through differen
# ...

# %%
## Directory loader 

from langchain_community.document_loaders import DirectoryLoader


## load all text files form the directory 
dir_loader =DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\sample.txt'}, page_content='Chapter 7\nRetrieval-Augmented Generation\nFilippo Bianchini\nAbstract Retrieval-augmented generation (RAG) has emerged as a transformative\napproach to enhancing the capabilities of large language models (LLMs) by\nintegrating real-time information retrieval with generative text synthesis. Traditional\nLLMs rely on pre-trained data, limiting their effectiveness when handling tasks\nrequiring up-to-date or domain-specific information. RAG addresses this constraint\nby embedding a retrieval mechanism within the LLM framework, allowing the\nmodel to access external knowledge sources dynamically. This integration enables\nLLMs to generate contextually relevant and factually accurate responses, extending\ntheir utility within the realm of information systems (IS), where timely and\nprecise information is critical. Starting from the history and evolution of retrievalaugmented generation, passing through diffe
# ...

# %%
## Directory loader 

from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader


## load all text files form the directory 
dir_loader =DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pfd_documents = dir_loader.load()
pfd_documents
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\sample.pdf', 'file_path': '..\\data\\pdf\\sample.pdf', 'total_pages': 34, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-09-26T11:27:20+00:00', 'trapped': '', 'modDate': 'D:20250926112720Z', 'creationDate': '', 'page': 0}, page_content='Chapter 7 \nRetrieval-Augmented Generation \nFilippo Bianchini \nAbstract Retrieval-augmented generation (RAG) has emerged as a transformative \napproach to enhancing the capabilities of large language models (LLMs) by \nintegrating real-time information retrieval with generative text synthesis. Traditional \nLLMs rely on pre-trained data, limiting their effectiveness when handling tasks \nrequiring up-to-date or domain-speciﬁc information. RAG addresses this constraint \nby embedding a retrieval mechanism within the LLM framework, allowing the \nmodel to access external knowledge sources dynamically
# ...
